# %% [markdown]
# # Data Exploration for NSE Stock Analysis
# This notebook aims to explore the raw stock data to assess quality, missing values, and date ranges.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\HP\OneDrive\Desktop\NSI\Nse-stock-analysis\data\ohlcv\HDFCBANK.csv')
  # Adjust the path to your data file
df.head()
# Out:
#          Date        Open        High         Low       Close    Volume
# 0  2023-11-13  726.183725  728.057453  723.166297  724.577698  20605914
# 1  2023-11-15  732.024014  735.357800  730.296316  732.170044  41245460
# 2  2023-11-16  734.749482  739.275684  731.853726  734.092468  29713838
# 3  2023-11-17  725.161799  733.678800  724.675113  732.510742  23701874
# 4  2023-11-20  736.355560  736.355560  730.783032  732.559387  19331452

# %%
# Step 1: Get overview of data structure
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    493 non-null    object
#  1   Open    493 non-null    float64
#  2   High    493 non-null    float64
#  3   Low     493 non-null    float64
#  4   Close   493 non-null    float64
#  5   Volume  493 non-null    int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 23.2+ KB

# %%
# Step 2: Summary statistics for numeric columns
df.describe()
# Out:
#               Open         High          Low        Close        Volume
# count   493.000000   493.000000   493.000000   493.000000  4.930000e+02
# mean    851.449540   858.418007   845.316471   851.896924  3.214720e+07
# std      95.414398    95.454622    95.146619    95.183143  3.284364e+07
# min     669.679568   677.223197   663.620355   673.597412  0.000000e+00
# 25%     795.941305   801.663895   788.837351   793.735779  1.801475e+07
# 50%     837.430443   844.583794   830.301830   838.565186  2.553574e+07
# 75%     949.170086   956.520728   943.743444   950.299988  3.579493e+07
# max    1016.320808  1020.500000  1008.500000  1012.900024  4.453421e+08

# %%
# Step 3: Check for missing values by column
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Step 4: Visualize missing values (optional, requires seaborn and matplotlib)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, yticklabels=False, cmap='viridis')
plt.title('Missing Data Heatmap')
plt.show()
